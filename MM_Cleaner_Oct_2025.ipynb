# %% [markdown]
# # Cleaning The Missing Migrants Files

# %% [markdown]
# ## A:  Import Cleaning Packages

# %%
# Install packages if not already installed
#!pip install pandas
#!pip install numpy
#!pip install geopy

# %%
# Packages for Cleaning the Dataset
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 1000)
pd.options.display.float_format = '{:,.12f}'.format
# %matplotlib inline

# %%
# Packages to find countries from coordinates
from geopy.geocoders import Nominatim

# %% [markdown]
# ## B: Import Dataset
# Online Excel and CSV files available

# %%
# Import the raw dataset from IOM
# https://missingmigrants.iom.int/downloads 
#MM = pd.read_excel('https://missingmigrants.iom.int/sites/g/files/tmzbdl601/files/report-migrant-incident/Missing_Migrants_Global_Figures_allData.xlsx', index_col = False)
MM = pd.read_csv('https://missingmigrants.iom.int/sites/g/files/tmzbdl601/files/report-migrant-incident/Missing_Migrants_Global_Figures_allData.csv?154546', index_col = False, encoding = 'unicode_escape')

# %% [markdown]
# ## C:  Columns to New IOM Column Format

# %%
# View DFs Original Column List
MM.columns
# Out:
# Index(['ï»¿"Main ID"', 'Incident ID', 'Incident Type', 'Region of Incident',
#        'Incident Date', 'Incident Year', 'Month', 'Number of Dead',
#        'Minimum Estimated Number of Missing',
#        'Total Number of Dead and Missing', 'Number of Survivors',
#        'Number of Females', 'Number of Males', 'Number of Children',
#        'Country of Origin', 'Region of Origin', 'Cause of Death',
#        'Country of Incident', 'Migration Route', 'Location of Incident',
#        'Coordinates', 'UNSD Geographical Grouping', 'Information Source',
#        'URL', 'Source Quality'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
MM.head()
# Out:
#     ï»¿"Main ID"    Incident ID Incident Type Region of Incident  \
# 0  2014.MMP00001  2014.MMP00001      Incident      North America
# 1  2014.MMP00002  2014.MMP00002      Incident      North America
# 2  2014.MMP00003  2014.MMP00003      Incident      North America
# 3  2014.MMP00004  2014.MMP00004      Incident      North America
# 4  2014.MMP00005  2014.MMP00005      Incident             Europe
#
#   Incident Date  Incident Year    Month  Number of Dead  \
# 0    2014-01-06           2014  January  1.000000000000
# 1    2014-01-12           2014  January  1.000000000000
# 2    2014-01-14           2014  January  1.000000000000
# 3    2014-01-16           2014  January  1.000000000000
# 4    2014-01-16           2014  January  1.000000000000
#
#    Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 0                       0.000000000000                                 1
# 1                       0.000000000000                                 1
# 2                       0.000000000000                                 1
# 3                       0.000000000000                                 1
# 4                       0.000000000000                                 1
#
#    Number of Survivors  Number of Females  Number of Males  \
# 0                  NaN                NaN   1.000000000000
# 1                  NaN     1.000000000000              NaN
# 2                  NaN                NaN   1.000000000000
# 3                  NaN                NaN   1.000000000000
# 4       2.000000000000                NaN   1.000000000000
#
#    Number of Children Country of Origin               Region of Origin  \
# 0                 NaN         Guatemala                Central America
# 1                 NaN           Unknown  Latin America / Caribbean (P)
# 2                 NaN           Unknown  Latin America / Caribbean (P)
# 3                 NaN            Mexico                Central America
# 4                 NaN             Sudan                Northern Africa
#
#                                       Cause of Death  \
# 0                                   Mixed or unknown
# 1                                   Mixed or unknown
# 2                                   Mixed or unknown
# 3                                           Violence
# 4  Harsh environmental conditions / lack of adequ...
#
#         Country of Incident            Migration Route  \
# 0  United States of America  US-Mexico border crossing
# 1  United States of America  US-Mexico border crossing
# 2  United States of America  US-Mexico border crossing
# 3  United States of America  US-Mexico border crossing
# 4        Russian Federation                        NaN
#
#                                 Location of Incident             Coordinates  \
# 0  Pima Country Office of the Medical Examiner ju...  31.650259, -110.366453
# 1  Pima Country Office of the Medical Examiner ju...    31.59713, -111.73756
# 2  Pima Country Office of the Medical Examiner ju...    31.94026, -113.01125
# 3                         near Douglas, Arizona, USA  31.506777, -109.315632
# 4                  Border between Russia and Estonia             59.1551, 28
#
#   UNSD Geographical Grouping  \
# 0           Northern America
# 1           Northern America
# 2           Northern America
# 3           Northern America
# 4            Northern Europe
#
#                                   Information Source  \
# 0  Pima County Office of the Medical Examiner (PC...
# 1  Pima County Office of the Medical Examiner (PC...
# 2  Pima County Office of the Medical Examiner (PC...
# 3  Ministry of Foreign Affairs Mexico, Pima Count...
# 4                  EUBusiness (Agence France-Presse)
#
#                           URL Source Quality
# 0  http://humaneborders.info/              5
# 1                         NaN              5
# 2                         NaN              5
# 3       http://bit.ly/1qfIw00              5
# 4       http://bit.ly/1rTFTjR              1

# %%
# Drop Useless Column
MM = MM.drop('ï»¿"Main ID"', axis = 1)

# %%
print(MM.columns)
# Out:
# Index(['Incident ID', 'Incident Type', 'Region of Incident', 'Incident Date',
#        'Incident Year', 'Month', 'Number of Dead',
#        'Minimum Estimated Number of Missing',
#        'Total Number of Dead and Missing', 'Number of Survivors',
#        'Number of Females', 'Number of Males', 'Number of Children',
#        'Country of Origin', 'Region of Origin', 'Cause of Death',
#        'Country of Incident', 'Migration Route', 'Location of Incident',
#        'Coordinates', 'UNSD Geographical Grouping', 'Information Source',
#        'URL', 'Source Quality'],
#       dtype='object')

# %%
# List New Column Names
columns = ["Incident_ID", "Incident_Type", "Region", "Reported_Date", "Reported_Year", 
              "Reported_Month", "Number_Dead", "Minimum_Missing", "Total_Dead_and_Missing", "Survivors", 
              "Females", "Males", "Children", "Country_of_Origin", "Region_of_Origin", "Cause_of_Death",
              "Country_of_Incident", "Migration_Route", "Location_Description", "Coordinates", "UNSD_Geographical_Grouping", 
           "Information_Source", "URL", "Source_Quality"]

# %%
# Ensure that your new columns are matching the DF
index = 0
for i in columns:
    print(f'{index + 1} - {columns[index]} ::: {MM.columns[index]}')
    index = index + 1
# Out:
# 1 - Incident_ID ::: Incident ID
# 2 - Incident_Type ::: Incident Type
# 3 - Region ::: Region of Incident
# 4 - Reported_Date ::: Incident Date
# 5 - Reported_Year ::: Incident Year
# 6 - Reported_Month ::: Month
# 7 - Number_Dead ::: Number of Dead
# 8 - Minimum_Missing ::: Minimum Estimated Number of Missing
# 9 - Total_Dead_and_Missing ::: Total Number of Dead and Missing
# 10 - Survivors ::: Number of Survivors
# 11 - Females ::: Number of Females
# 12 - Males ::: Number of Males
# 13 - Children ::: Number of Children
# 14 - Country_of_Origin ::: Country of Origin
# 15 - Region_of_Origin ::: Region of Origin
# 16 - Cause_of_Death ::: Cause of Death
# 17 - Country_of_Incident ::: Country of Incident
# 18 - Migration_Route ::: Migration Route
# 19 - Location_Description ::: Location of Incident
# 20 - Coordinates ::: Coordinates
# 21 - UNSD_Geographical_Grouping ::: UNSD Geographical Grouping
# 22 - Information_Source ::: Information Source
# 23 - URL ::: URL
# 24 - Source_Quality ::: Source Quality

# %%
# Set new column names
MM.columns = columns

# %%
print(MM.head())
# Out:
#      Incident_ID Incident_Type         Region Reported_Date  Reported_Year  \
# 0  2014.MMP00001      Incident  North America    2014-01-06           2014
# 1  2014.MMP00002      Incident  North America    2014-01-12           2014
# 2  2014.MMP00003      Incident  North America    2014-01-14           2014
# 3  2014.MMP00004      Incident  North America    2014-01-16           2014
# 4  2014.MMP00005      Incident         Europe    2014-01-16           2014
#
#   Reported_Month    Number_Dead  Minimum_Missing  Total_Dead_and_Missing  \
# 0        January 1.000000000000   0.000000000000                       1
# 1        January 1.000000000000   0.000000000000                       1
# 2        January 1.000000000000   0.000000000000                       1
# 3        January 1.000000000000   0.000000000000                       1
# 4        January 1.000000000000   0.000000000000                       1
#
#        Survivors        Females          Males  Children Country_of_Origin  \
# 0            NaN            NaN 1.000000000000       NaN         Guatemala
# 1            NaN 1.000000000000            NaN       NaN           Unknown
# 2            NaN            NaN 1.000000000000       NaN           Unknown
# 3            NaN            NaN 1.000000000000       NaN            Mexico
# 4 2.000000000000            NaN 1.000000000000       NaN             Sudan
#
#                 Region_of_Origin  \
# 0                Central America
# 1  Latin America / Caribbean (P)
# 2  Latin America / Caribbean (P)
# 3                Central America
# 4                Northern Africa
#
#                                       Cause_of_Death  \
# 0                                   Mixed or unknown
# 1                                   Mixed or unknown
# 2                                   Mixed or unknown
# 3                                           Violence
# 4  Harsh environmental conditions / lack of adequ...
#
#         Country_of_Incident            Migration_Route  \
# 0  United States of America  US-Mexico border crossing
# 1  United States of America  US-Mexico border crossing
# 2  United States of America  US-Mexico border crossing
# 3  United States of America  US-Mexico border crossing
# 4        Russian Federation                        NaN
#
#                                 Location_Description             Coordinates  \
# 0  Pima Country Office of the Medical Examiner ju...  31.650259, -110.366453
# 1  Pima Country Office of the Medical Examiner ju...    31.59713, -111.73756
# 2  Pima Country Office of the Medical Examiner ju...    31.94026, -113.01125
# 3                         near Douglas, Arizona, USA  31.506777, -109.315632
# 4                  Border between Russia and Estonia             59.1551, 28
#
#   UNSD_Geographical_Grouping  \
# 0           Northern America
# 1           Northern America
# 2           Northern America
# 3           Northern America
# 4            Northern Europe
#
#                                   Information_Source  \
# 0  Pima County Office of the Medical Examiner (PC...
# 1  Pima County Office of the Medical Examiner (PC...
# 2  Pima County Office of the Medical Examiner (PC...
# 3  Ministry of Foreign Affairs Mexico, Pima Count...
# 4                  EUBusiness (Agence France-Presse)
#
#                           URL Source_Quality
# 0  http://humaneborders.info/              5
# 1                         NaN              5
# 2                         NaN              5
# 3       http://bit.ly/1qfIw00              5
# 4       http://bit.ly/1rTFTjR              1

# %% [markdown]
# ## D: Cleaning Cause_of_Death and Removing all NANS

# %%
MM['Country_of_Origin'].unique()
# Out:
# array(['Guatemala', 'Unknown', 'Mexico', 'Sudan', 'Afghanistan',
#        'Iran (Islamic Republic of)', 'Haiti', 'Myanmar', 'Cameroon',
#        'Somalia', 'Bangladesh', 'Ethiopia', 'Albania', 'Cambodia',
#        'Ecuador', 'El Salvador', 'Syrian Arab Republic', 'Congo',
#        'Zimbabwe', 'Eritrea,Ethiopia,Sudan,Unknown', 'Honduras,Mexico',
#        'China', 'Eritrea,Ethiopia,Somalia', 'Eritrea', 'Niger',
#        'Ethiopia,Somalia', 'Central African Republic', 'Indonesia',
#        'Morocco,Syrian Arab Republic,Unknown',
#        'Cameroon,Somalia,Syrian Arab Republic',
#        'Eritrea,Syrian Arab Republic,Unknown',
#        'Egypt,Syrian Arab Republic',
#        "CÃ´te d'Ivoire,Eritrea,Guinea,Libya,Mali,Palestinian Territories,Somalia,Sudan,Syrian Arab Republic",
#        'Cuba', 'Dominican Republic,Haiti',
#        'Egypt,Palestinian Territories,Sudan,Syrian Arab Republic',
#        'Egypt,State of Palestine,Syrian Arab Republic', 'Honduras',
#        'Dominican Republic', 'Peru', 'State of Palestine,Sudan',
#        'Nigeria', 'Guinea', 'Ghana', 'Iran (Islamic Republic of),Iraq',
#        "CÃ´te d'Ivoire,Guinea,Mali,Mauritania,Senegal",
#        "CÃ´te d'Ivoire,Gambia,Guinea,Mali,Mauritania,Niger,Senegal",
#        'El Salvador,Guatemala,Mexico,Unknown', 'Eritrea,Sudan,Unknown',
#        'Iraq', 'Iraq,Syrian Arab Republic', 'Honduras,Unknown',
#        'Nigeria,Unknown', 'Cuba,Dominican Republic',
#        'Iran (Islamic Republic of),Syrian Arab Republic',
#        'Eritrea,Somalia', 'Costa Rica', 'Ghana,Niger',
#        "Algeria,Bangladesh,CÃ´te d'Ivoire,Egypt,Eritrea,Gambia,Ghana,Guinea,Mali,Niger,Sierra Leone,Somalia,Sudan,Syrian Arab Republic,Tunisia,Zambia",
#        'Eritrea,Syrian Arab Republic', 'Mixed/Unknown',
#        'Mali,Nigeria,Senegal,Unknown', nan, 'Madagascar', 'Tunisia',
#        'Bangladesh,Myanmar', "CÃ´te d'Ivoire,Unknown",
#        "Central African Republic,CÃ´te d'Ivoire,Guinea,Liberia,Mali,Nigeria,Senegal",
#        'Gambia,Guinea-Bissau', 'Mozambique', 'El Salvador,Guatemala',
#        'Guatemala,Honduras', 'Pakistan',
#        'Bangladesh,Egypt,Nepal,Sudan,Syrian Arab Republic',
#        'Cameroon,Nigeria', 'Morocco', 'Syrian Arab Republic,Unknown',
#        'Nicaragua', 'Cameroon,Ghana,Mali,Nigeria,Unknown',
#        'Bangladesh,Pakistan,Unknown', 'State of Palestine',
#        'Iraq,TÃ¼rkiye', 'Afghanistan,Syrian Arab Republic',
#        'Afghanistan,Iraq,Syrian Arab Republic,Unknown',
#        'Bangladesh,Syrian Arab Republic,Unknown', 'Nigeria,Somalia,Sudan',
#        'Gambia,Nigeria,Senegal', 'Guatemala,Honduras,Mexico',
#        'Cameroon,Guinea', 'Lebanon',
#        'Afghanistan,Syrian Arab Republic,Unknown', 'Senegal', 'Comoros',
#        'Egypt', 'Iraq,Syrian Arab Republic,Unknown',
#        'Guinea,Mali,Unknown', 'Afghanistan,Iraq,Syrian Arab Republic',
#        'Malawi', 'Venezuela (Bolivarian Republic of)',
#        'Afghanistan,Iran (Islamic Republic of)',
#        'Algeria,Iraq,Syrian Arab Republic',
#        'Pakistan,Sierra Leone,Somalia', 'India', 'El Salvador,Honduras',
#        'Malawi,Zimbabwe', 'Algeria', 'Libya,Tunisia',
#        'Bangladesh,Sudan,Unknown',
#        'Egypt,Ethiopia,Somalia,Sudan,Syrian Arab Republic',
#        "Cameroon,CÃ´te d'Ivoire,Gambia,Mauritania,Unknown",
#        "CÃ´te d'Ivoire,Guinea,Mali,Nigeria,Sudan",
#        "CÃ´te d'Ivoire,Guinea", 'Nepal', 'Morocco,Unknown',
#        "CÃ´te d'Ivoire,Eritrea,Gambia,Nigeria,Somalia,South Sudan",
#        'Comoros,Egypt,Eritrea,Ethiopia,Sudan', 'Niger,Unknown',
#        'Mexico,Unknown', 'Mali', 'Colombia',
#        'Brazil,Ecuador,Nicaragua,Unknown', 'Tunisia,Unknown', 'Mixed',
#        "CÃ´te d'Ivoire,Gambia,Guinea", 'El Salvador,Guatemala,Honduras',
#        'Papua New Guinea', 'Cuba,Unknown',
#        'Egypt,Eritrea,Sudan,Syrian Arab Republic', 'Afghanistan,Pakistan',
#        'Libya,Morocco,Syrian Arab Republic', "CÃ´te d'Ivoire",
#        'Ecuador,Guatemala', 'Nigeria,Senegal',
#        'Unknown,Venezuela (Bolivarian Republic of)',
#        'Guinea,Mali,Senegal', 'Brazil,Cuba,Dominican Republic', 'Brazil',
#        "Cameroon,CÃ´te d'Ivoire,Senegal", 'Romania', 'Senegal,Unknown',
#        'Democratic Republic of the Congo', 'Congo,Morocco,Unknown',
#        'Mali,Senegal', 'Gambia,Unknown', 'Ghana,Guinea,Senegal',
#        'Cameroon,Congo,Syrian Arab Republic,TÃ¼rkiye', 'Gambia',
#        'Bangladesh,Senegal,Unknown', 'Ghana,Nigeria', 'Sudan,Unknown',
#        'Chad', 'Egypt,Unknown', 'Guinea,Mali',
#        'Ecuador,Guatemala,Mexico,Unknown', 'Guatemala,Unknown',
#        "Burkina Faso,CÃ´te d'Ivoire,Gambia,Nigeria", 'Congo,Guinea',
#        'Angola,Congo', 'Cameroon,Unknown', 'Burkina Faso', 'Libya',
#        'TÃ¼rkiye,Unknown', 'Eritrea,Unknown', 'El Salvador,Mexico',
#        'Guatemala,Mexico', 'Kazakhstan',
#        "Cameroon,CÃ´te d'Ivoire,Guinea,Mali,Nigeria,Sierra Leone",
#        'Uzbekistan', 'El Salvador,Honduras,Unknown',
#        'Ethiopia,Somalia,Unknown', 'Libya,Pakistan,Unknown',
#        "CÃ´te d'Ivoire,Guinea,Mali", 'TÃ¼rkiye', 'Sierra Leone',
#        'Afghanistan,Iraq,Unknown', 'Viet Nam', 'Burundi',
#        'Afghanistan,Iran (Islamic Republic of),Pakistan',
#        'Liberia,Unknown', "CÃ´te d'Ivoire,Tunisia,Unknown",
#        'Nigeria,Sudan', 'Mali,Senegal,Unknown', 'Bangladesh,Unknown',
#        'Somalia,Unknown', 'Gambia,Senegal',
#        "Cameroon,CÃ´te d'Ivoire,Democratic Republic of the Congo,Tunisia",
#        'Mali,Unknown', 'Afghanistan,Unknown', 'Bahamas,Haiti', 'Ukraine',
#        'Togo', 'Cameroon,Guinea,Unknown', 'Myanmar,Viet Nam',
#        'Unknown,Yemen', 'Angola,Cuba',
#        "CÃ´te d'Ivoire,Mali,Senegal,Unknown",
#        'Bangladesh,Egypt,Morocco,Unknown', 'Guinea,Senegal',
#        'Somalia,State of Palestine,Syrian Arab Republic,Yemen',
#        'Mixed,Unknown', 'India,Pakistan', 'Kenya', 'Eritrea,Sudan',
#        'Eritrea,Ethiopia', "Lao People's Democratic Republic",
#        'Egypt,Pakistan', 'Morocco,Somalia,Unknown',
#        "CÃ´te d'Ivoire,Mali,Unknown", 'Bangladesh,Mixed', 'Yemen',
#        'Georgia', 'Belize',
#        'Algeria,Eritrea,Libya,Morocco,Nigeria,Unknown',
#        "Democratic People's Republic of Korea", 'Lesotho',
#        'Afghanistan,Iraq,Somalia,Syrian Arab Republic,Unknown',
#        'Mauritania', 'Liberia',
#        'Afghanistan,Pakistan,Syrian Arab Republic',
#        'Algeria,Tunisia,Unknown', 'Guinea,Unknown', 'South Sudan',
#        'Chad,Egypt,Nigeria,Sudan', 'Oman', 'Guinea,Mexico,Sudan',
#        'Bangladesh,Pakistan', 'Libya,Niger', 'Egypt,Gambia',
#        "Cameroon,CÃ´te d'Ivoire,Guinea,Mali,Niger,Sudan",
#        'Republic of Korea',
#        'Ethiopia,Ghana,Nigeria,Syrian Arab Republic,Unknown',
#        'Ghana,Sudan,Unknown', 'Libya,Unknown',
#        'Algeria,Syrian Arab Republic', 'Libya,Morocco,Unknown',
#        'Algeria,Egypt,Morocco',
#        'Algeria,Benin,Mali,Morocco,Niger,Unknown',
#        'Libya,Syrian Arab Republic,Unknown', 'Pakistan,Unknown',
#        "Cameroon,CÃ´te d'Ivoire,Gambia,Guinea,Togo",
#        "CÃ´te d'Ivoire,Sudan,Unknown", 'Algeria,Unknown', 'Sri Lanka',
#        'Afghanistan,Bangladesh,Nigeria,Pakistan',
#        "CÃ´te d'Ivoire,Guinea,Mali,Senegal",
#        "CÃ´te d'Ivoire,Mali,Nigeria,Senegal,Togo",
#        'Guatemala,Mexico,Unknown',
#        "CÃ´te d'Ivoire,Gambia,Ghana,Guinea,Nigeria,Togo",
#        'Colombia,Venezuela (Bolivarian Republic of)', 'Chad,Unknown',
#        'Guyana', 'Libya,Sudan,Unknown', 'Chad,Sudan',
#        'Cameroon,Guinea,Mali,Nigeria,Sierra Leone,Sudan',
#        'Argentina,Bolivia (Plurinational State of),Unknown',
#        'Bahamas,Guyana,Jamaica', 'Bolivia (Plurinational State of)',
#        'Sierra Leone,Somalia', 'Egypt,Pakistan,Unknown',
#        'Guinea,Senegal,Unknown', 'Iraq,Unknown', 'Gambia,Ghana,Nigeria',
#        'Comoros,Unknown', "CÃ´te d'Ivoire,Egypt,Sudan,Tunisia",
#        "CÃ´te d'Ivoire,Guinea,Unknown", 'Cuba,Haiti,Mixed',
#        "CÃ´te d'Ivoire,Gambia,Ghana,Guinea,Senegal",
#        'Afghanistan,Egypt,Ethiopia,Iran (Islamic Republic of),Iraq,Somalia,Viet Nam',
#        'Dominican Republic,Ecuador,Guatemala,Unknown',
#        'Bangladesh,Egypt,Guinea,Pakistan',
#        "Cameroon,CÃ´te d'Ivoire,Ghana,Guinea,Mali,Nigeria,Senegal,Togo,Unknown",
#        'Gambia,Guinea,Nigeria,Senegal', 'Mixed/Unknown,Unknown',
#        'Mali,Mixed', 'Paraguay', 'Cameroon,Ghana',
#        'Colombia,Dominican Republic,Unknown',
#        'Bangladesh,Somalia,Unknown', 'Eswatini', "CÃ´te d'Ivoire,Eritrea",
#        'Israel', 'Egypt,Mixed,Syrian Arab Republic,Unknown',
#        'Mixed,Syrian Arab Republic,Tunisia', 'Uruguay', 'Mali,Sudan',
#        'Democratic Republic of the Congo,Unknown',
#        'Lebanon,State of Palestine,Syrian Arab Republic', 'Angola',
#        'Niger,Sudan', 'Gambia,Mali,Nigeria', 'Nicaragua,Unknown',
#        'Sudan,Tunisia,Unknown', 'Jamaica',
#        "Burkina Faso,Cameroon,Central African Republic,CÃ´te d'Ivoire,Mali",
#        "CÃ´te d'Ivoire,Gambia,Mali,Unknown", 'Chad,Libya',
#        'Libya,Syrian Arab Republic', 'Honduras,Mexico,Unknown',
#        "CÃ´te d'Ivoire,Guinea,Nigeria,Unknown",
#        'Nicaragua,Venezuela (Bolivarian Republic of)', 'Somalia,Yemen',
#        'Colombia,Mixed,Venezuela (Bolivarian Republic of)',
#        'Egypt,Syrian Arab Republic,TÃ¼rkiye',
#        'Cuba,Ecuador,Mixed,Venezuela (Bolivarian Republic of)',
#        'Kyrgyzstan', 'Mixed/Unknown,Morocco', 'Egypt,Mixed,Sudan',
#        'Egypt,Mixed', 'Peru,Unknown',
#        'Brazil,Venezuela (Bolivarian Republic of)',
#        'Bangladesh,Egypt,Syrian Arab Republic', 'Niger,Nigeria,Sudan',
#        'Cameroon,Ghana,Nigeria,Somalia,Sudan',
#        'Egypt,Palestinian Territories,Unknown', 'Algeria,Guinea,Mali',
#        'Russian Federation', 'Mexico,Venezuela (Bolivarian Republic of)',
#        'Ecuador,Thailand,Venezuela (Bolivarian Republic of)',
#        'Chad,Guinea-Bissau,Unknown', 'Niger,Sudan,Unknown',
#        'Democratic Republic of the Congo,Haiti,Mali,Unknown',
#        "Cameroon,CÃ´te d'Ivoire", 'Nigeria,Sudan,Unknown',
#        'Guatemala,Honduras,Unknown', 'Colombia,Ecuador,Mixed,Unknown',
#        'Colombia,Unknown',
#        'Afghanistan,Pakistan,State of Palestine,Tunisia,Unknown',
#        'Colombia,Haiti,Unknown',
#        'Democratic Republic of the Congo,Liberia,Somalia',
#        'El Salvador,Guatemala,Mexico,Nicaragua', 'Algeria,Guinea,Unknown',
#        'Canada,India,Romania', 'Palestinian Territories',
#        'Egypt,Pakistan,Syrian Arab Republic,Unknown',
#        "CÃ´te d'Ivoire,Mixed,Unknown", 'Burkina Faso,Unknown',
#        'Colombia,El Salvador,Guatemala,Honduras,Unknown,Venezuela (Bolivarian Republic of)',
#        'Republic of Moldova,Syrian Arab Republic', 'Liberia,Mali',
#        'Mixed,Syrian Arab Republic',
#        'Gambia,Mali,Nigeria,Senegal,Unknown',
#        'Sierra Leone,Sudan,Unknown', 'Algeria,Morocco',
#        'Mauritania,Unknown', 'Bangladesh,Egypt,Unknown',
#        "CÃ´te d'Ivoire,Guinea,Mali,Senegal,Unknown", 'Mali,Nigeria',
#        'Chad,Niger', 'Niger,Nigeria', 'Colombia,Ecuador',
#        'Ethiopia,Niger,Syrian Arab Republic,Unknown',
#        'Haiti,Mixed,Venezuela (Bolivarian Republic of)',
#        'Liberia,State of Palestine,Syrian Arab Republic,Unknown',
#        'Iran (Islamic Republic of),Unknown',
#        'Haiti,Unknown,Venezuela (Bolivarian Republic of)',
#        'Eritrea,Mali,Niger', "CÃ´te d'Ivoire,Nigeria",
#        'South Sudan,Sudan', 'Gambia,Nigeria', 'Gambia,Niger', 'Malaysia',
#        'Mixed,Syrian Arab Republic,Unknown', 'Benin',
#        'Mali,Mauritania,Unknown', 'Mali,Mixed/Unknown',
#        'Cameroon,Mali,Senegal',
#        'Bangladesh,Ethiopia,Syrian Arab Republic',
#        "CÃ´te d'Ivoire,Mixed/Unknown", 'India,Iraq,Sudan,TÃ¼rkiye',
#        'Dominican Republic,Ecuador', 'Hungary,Iran (Islamic Republic of)',
#        'Iraq,Mixed,Unknown', 'Ecuador,Mexico',
#        'Afghanistan,Iraq,State of Palestine,Unknown',
#        'Mauritania,Mixed/Unknown,Senegal', 'Honduras,Nicaragua',
#        'Egypt,Iraq,Syrian Arab Republic,Unknown', 'Kuwait', 'Mixed,Sudan',
#        'Ecuador,Nicaragua', 'Egypt,Eritrea,Iraq,Sudan,Viet Nam',
#        'Cameroon,Syrian Arab Republic', 'Bangladesh,Eritrea,Somalia',
#        'Pakistan,Syrian Arab Republic,Unknown', 'Egypt,El Salvador,Peru',
#        'Ethiopia,Viet Nam', 'Egypt,Sudan',
#        'Egypt,Eritrea,Ethiopia,Syrian Arab Republic',
#        'Bangladesh,Mixed/Unknown,Unknown', 'Iraq,Somalia', 'Chad,Nigeria',
#        'Guinea,Mali,Sudan', 'Afghanistan,Egypt,Unknown',
#        "Congo,CÃ´te d'Ivoire,Nigeria,Somalia,Unknown",
#        'Egypt,Syrian Arab Republic,Unknown', 'Bangladesh,Iraq,Pakistan',
#        'Thailand', 'Jordan', 'Gambia,Guinea,Unknown', 'Benin,Senegal',
#        'Egypt,India,Iran (Islamic Republic of),Unknown',
#        'Algeria,Morocco,Unknown',
#        'Burkina Faso,Ethiopia,Nigeria,South Sudan,Sudan',
#        'Guinea,Mauritania,Sudan,Unknown,Yemen', 'India,Mexico',
#        'Ethiopia,Unknown', 'Suriname', 'Egypt,Libya,Sudan',
#        'Egypt,Eritrea,Pakistan,Sudan,Unknown',
#        'Dominican Republic,Haiti,Unknown', 'Guinea,Somalia',
#        'Egypt,Viet Nam', 'Philippines', 'Senegal,Syrian Arab Republic',
#        'Mali,Morocco'], dtype=object)

# %%
type(MM['Country_of_Origin'][1])
# Out:
# str

# %%
new_coo = []
index = 0
for i in MM['Country_of_Origin']:
    if type(MM['Country_of_Origin'][index]) != str:
        MM['Country_of_Origin'][index] = str(MM['Country_of_Origin'][index])
    else:
        pass
    index = index + 1
# Out:
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/4271802594.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = str(MM['Country_of_Origin'][index])
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/4271802594.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = str(MM['Country_of_Origin'][index])
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/4271802594.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = str(MM['Country_of_Origin'][index])
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/4271802594.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = str(MM['Country_of_Origin'][index])

# %%
for i in new_coo:
    print(type())

# %%
print(new_coo)
# Out:
# []

# %%
new_coo2 = []
index = 0
for i in MM['Country_of_Origin']:
    if type(MM.loc[index, 'Country_of_Origin']) != str:
        MM.loc[index, 'Country_of_Origin'] = str(MM.loc[index,'Country_of_Origin'])
    else:
        pass
    index = index + 1

# %%
for i in new_coo2:
    print(type())

# %%
print(new_coo)
# Out:
# []

# %%
index = 0
infrequent_countries = ['nan', 'Viet Nam', 'Liberia', 'Burundi', 'Lesotho', 'Mauritania', 'Malawi', 'Uzbekistan', 'Nepal', 'Madagascar',
                        'Mozambique', 'Lebanon', 'Costa Rica', 'Malaysia', 'Kenya', 'Central African Republic', 'Kyrgyzstan', 'Jamaica',
                        'Uruguay', 'Israel', 'Eswatini', 'Paraguay', 'Albania', 'Guyana', 'Republic of Korea', "Lao People's Democratic Republic",
                        'Oman', 'South Sudan', 'Burkina Faso', 'Bahamas', 'Papua New Guinea', 'Belize', 'Georgia', 'Togo', 'Russian Federation']
for i in MM['Country_of_Origin']:
    if "Unknown" in MM['Country_of_Origin'][index]:
        MM['Country_of_Origin'][index] = "Unknown"
    elif "," in MM['Country_of_Origin'][index]:
        MM['Country_of_Origin'][index] = "Multiple Countries"
    elif "Mixed" in MM['Country_of_Origin'][index]:
        MM['Country_of_Origin'][index] = "Multiple Countries"
    elif "multiple" in MM['Country_of_Origin'][index]:
        MM['Country_of_Origin'][index] = "Multiple Countries"
    elif MM['Country_of_Origin'][index] in infrequent_countries:
        MM["Country_of_Origin"][index] = "Infrequent Countries"
    else:
        pass
    index = index + 1
# Out:
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM["Country_of_Origin"][index] = "Infrequent Countries"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM["Country_of_Origin"][index] = "Infrequent Countries"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Multiple Countries"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Multiple Countries"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   MM['Country_of_Origin'][index] = "Unknown"
# /var/folders/sr/zpmlq7p515qfntn1zl8_zf340000gn/T/ipykernel_1644/3157776541.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MM['Country_of_Origin'][index] = "Unknown"
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
MM["Country_of_Origin"].value_counts()
# Out:
# Country_of_Origin
# Unknown                                  9124
# Afghanistan                              4429
# Mexico                                   1565
# Guatemala                                 550
# Ethiopia                                  478
# Honduras                                  402
# Venezuela (Bolivarian Republic of)        348
# Syrian Arab Republic                      347
# Multiple Countries                        286
# El Salvador                               194
# Morocco                                   186
# Algeria                                   175
# Myanmar                                   170
# Cuba                                      161
# Haiti                                     147
# Sudan                                     122
# Ecuador                                   114
# Nicaragua                                  83
# Infrequent Countries                       82
# Egypt                                      73
# Dominican Republic                         70
# Colombia                                   62
# Iraq                                       62
# Pakistan                                   61
# Tunisia                                    60
# Bangladesh                                 56
# Nigeria                                    54
# Guinea                                     54
# Niger                                      54
# Eritrea                                    50
# Somalia                                    43
# Senegal                                    40
# CÃ´te d'Ivoire                             29
# Indonesia                                  27
# Cambodia                                   25
# Yemen                                      23
# Chad                                       23
# Mali                                       22
# Ukraine                                    21
# Comoros                                    20
# India                                      19
# Iran (Islamic Republic of)                 18
# TÃ¼rkiye                                   17
# Peru                                       17
# Brazil                                     16
# Gambia                                     16
# Cameroon                                   16
# Democratic Republic of the Congo           15
# China                                      14
# Bolivia (Plurinational State of)           14
# Ghana                                      11
# State of Palestine                         10
# Sierra Leone                                9
# Democratic People's Republic of Korea       9
# Sri Lanka                                   9
# Zimbabwe                                    6
# Congo                                       5
# Libya                                       5
# Angola                                      3
# Kuwait                                      2
# Romania                                     2
# Palestinian Territories                     1
# Benin                                       1
# Kazakhstan                                  1
# Thailand                                    1
# Jordan                                      1
# Suriname                                    1
# Philippines                                 1
# Name: count, dtype: int64

# %%
# Create a list to show all the possible causes of death
death_list = []
index = 0
for i in MM["Cause_of_Death"]:
    if not MM["Cause_of_Death"][index] in death_list:
        death_list.append(MM["Cause_of_Death"][index])
    else:
        pass
    index = index + 1

print(death_list)
# Out:
# ['Mixed or unknown', 'Violence', 'Harsh environmental conditions / lack of adequate shelter, food, water', 'Drowning', 'Vehicle accident / death linked to hazardous transport', 'Sickness / lack of access to adequate healthcare', 'Accidental death', 'Drowning,Mixed or unknown', 'Drowning,Harsh environmental conditions / lack of adequate shelter, food, water', 'Drowning,Vehicle accident / death linked to hazardous transport', 'Harsh environmental conditions / lack of adequate shelter, food, water,Sickness / lack of access to adequate healthcare', 'Harsh environmental conditions / lack of adequate shelter, food, water,Mixed or unknown', 'Drowning,Violence', 'Mixed or unknown,Vehicle accident / death linked to hazardous transport,Violence', 'Drowning,Sickness / lack of access to adequate healthcare', 'Accidental death,Drowning', 'Mixed or unknown,Sickness / lack of access to adequate healthcare', 'Mixed or unknown,Vehicle accident / death linked to hazardous transport']

# %%
# View Unbucketed Value Counts
MM['Cause_of_Death'].value_counts()
# Out:
# Cause_of_Death
# Drowning                                                                                                                   4665
# Mixed or unknown                                                                                                           4317
# Vehicle accident / death linked to hazardous transport                                                                     3122
# Sickness / lack of access to adequate healthcare                                                                           2590
# Harsh environmental conditions / lack of adequate shelter, food, water                                                     2487
# Violence                                                                                                                   2010
# Accidental death                                                                                                            904
# Drowning,Harsh environmental conditions / lack of adequate shelter, food, water                                              12
# Drowning,Mixed or unknown                                                                                                     7
# Harsh environmental conditions / lack of adequate shelter, food, water,Sickness / lack of access to adequate healthcare       4
# Harsh environmental conditions / lack of adequate shelter, food, water,Mixed or unknown                                       3
# Drowning,Violence                                                                                                             3
# Drowning,Sickness / lack of access to adequate healthcare                                                                     3
# Accidental death,Drowning                                                                                                     1
# Mixed or unknown,Sickness / lack of access to adequate healthcare                                                             1
# Drowning,Vehicle accident / death linked to hazardous transport                                                               1
# Mixed or unknown,Vehicle accident / death linked to hazardous transport,Violence                                              1
# Mixed or unknown,Vehicle accident / death linked to hazardous transport                                                       1
# Name: count, dtype: int64

# %%
# For Items with Few Incidents:
#Bucketing Causes of Death

index = 0
for i in MM['Cause_of_Death']:
    if "lack of adequate shelter, food, water" in MM["Cause_of_Death"][index]:
        MM['Cause_of_Death'][index] = "Lack of Shelter, Food, or Water"
    index = index + 1
    
index = 0
for i in MM['Cause_of_Death']:
    if "Mixed or unknown" in MM["Cause_of_Death"][index]:
        MM['Cause_of_Death'][index] = "Mixed or unknown"
    index = index + 1
    
index = 0
for i in MM['Cause_of_Death']:
    if "Drowning" in MM["Cause_of_Death"][index]:
        MM['Cause_of_Death'][index] = "Drowning"
    index = index + 1
    
index = 0
for i in MM['Cause_of_Death']:
    if MM['Cause_of_Death'][index] == 'Harsh environmental conditions / lack of adequate shelter, food, water':
        MM['Cause_of_Death'][index] = "Lack of Shelter, Food, or Water"
    index = index + 1
    
index = 0
for i in MM['Cause_of_Death']:
    if MM['Cause_of_Death'][index] == 'Harsh environmental conditions / lack of adequate shelter, food, water':
        MM['Cause_of_Death'][index] = "Lack of Shelter, Food, or Water"
    index = index + 1
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Bucketed Value Counts
MM['Cause_of_Death'].value_counts()
# Out:
# Cause_of_Death
# Drowning                                                  4673
# Mixed or unknown                                          4327
# Vehicle accident / death linked to hazardous transport    3122
# Sickness / lack of access to adequate healthcare          2590
# Lack of Shelter, Food, or Water                           2506
# Violence                                                  2010
# Accidental death                                           904
# Name: count, dtype: int64

# %%
print(MM.head())
# Out:
#      Incident_ID Incident_Type         Region Reported_Date  Reported_Year  \
# 0  2014.MMP00001      Incident  North America    2014-01-06           2014
# 1  2014.MMP00002      Incident  North America    2014-01-12           2014
# 2  2014.MMP00003      Incident  North America    2014-01-14           2014
# 3  2014.MMP00004      Incident  North America    2014-01-16           2014
# 4  2014.MMP00005      Incident         Europe    2014-01-16           2014
#
#   Reported_Month    Number_Dead  Minimum_Missing  Total_Dead_and_Missing  \
# 0        January 1.000000000000   0.000000000000                       1
# 1        January 1.000000000000   0.000000000000                       1
# 2        January 1.000000000000   0.000000000000                       1
# 3        January 1.000000000000   0.000000000000                       1
# 4        January 1.000000000000   0.000000000000                       1
#
#        Survivors        Females          Males  Children Country_of_Origin  \
# 0            NaN            NaN 1.000000000000       NaN         Guatemala
# 1            NaN 1.000000000000            NaN       NaN           Unknown
# 2            NaN            NaN 1.000000000000       NaN           Unknown
# 3            NaN            NaN 1.000000000000       NaN            Mexico
# 4 2.000000000000            NaN 1.000000000000       NaN             Sudan
#
#                 Region_of_Origin                   Cause_of_Death  \
# 0                Central America                 Mixed or unknown
# 1  Latin America / Caribbean (P)                 Mixed or unknown
# 2  Latin America / Caribbean (P)                 Mixed or unknown
# 3                Central America                         Violence
# 4                Northern Africa  Lack of Shelter, Food, or Water
#
#         Country_of_Incident            Migration_Route  \
# 0  United States of America  US-Mexico border crossing
# 1  United States of America  US-Mexico border crossing
# 2  United States of America  US-Mexico border crossing
# 3  United States of America  US-Mexico border crossing
# 4        Russian Federation                        NaN
#
#                                 Location_Description             Coordinates  \
# 0  Pima Country Office of the Medical Examiner ju...  31.650259, -110.366453
# 1  Pima Country Office of the Medical Examiner ju...    31.59713, -111.73756
# 2  Pima Country Office of the Medical Examiner ju...    31.94026, -113.01125
# 3                         near Douglas, Arizona, USA  31.506777, -109.315632
# 4                  Border between Russia and Estonia             59.1551, 28
#
#   UNSD_Geographical_Grouping  \
# 0           Northern America
# 1           Northern America
# 2           Northern America
# 3           Northern America
# 4            Northern Europe
#
#                                   Information_Source  \
# 0  Pima County Office of the Medical Examiner (PC...
# 1  Pima County Office of the Medical Examiner (PC...
# 2  Pima County Office of the Medical Examiner (PC...
# 3  Ministry of Foreign Affairs Mexico, Pima Count...
# 4                  EUBusiness (Agence France-Presse)
#
#                           URL Source_Quality
# 0  http://humaneborders.info/              5
# 1                         NaN              5
# 2                         NaN              5
# 3       http://bit.ly/1qfIw00              5
# 4       http://bit.ly/1rTFTjR              1

# %%
# B. Replacing missing values 

#Replacing nan in "Cause_of_Death" with "unknown"
MM['Cause_of_Death'] = MM['Cause_of_Death'].replace(np.nan, "Unknown")

#Replacing nan in "Migration_Route" with "Not specified"
MM['Migration_Route'] = MM['Migration_Route'].replace(np.nan, "Not Specified")

#Replacing nan in "Region" with "Not specified"
MM['Region'] = MM['Region'].replace(np.nan, "Not Specified")

#Replacing the NA figures in numerical columns with 0 
MM.iloc[:, 6:13] = MM.iloc[:, 6:13].fillna(int(0))

# %%
print(MM.head())
# Out:
#      Incident_ID Incident_Type         Region Reported_Date  Reported_Year  \
# 0  2014.MMP00001      Incident  North America    2014-01-06           2014
# 1  2014.MMP00002      Incident  North America    2014-01-12           2014
# 2  2014.MMP00003      Incident  North America    2014-01-14           2014
# 3  2014.MMP00004      Incident  North America    2014-01-16           2014
# 4  2014.MMP00005      Incident         Europe    2014-01-16           2014
#
#   Reported_Month    Number_Dead  Minimum_Missing  Total_Dead_and_Missing  \
# 0        January 1.000000000000   0.000000000000                       1
# 1        January 1.000000000000   0.000000000000                       1
# 2        January 1.000000000000   0.000000000000                       1
# 3        January 1.000000000000   0.000000000000                       1
# 4        January 1.000000000000   0.000000000000                       1
#
#        Survivors        Females          Males       Children  \
# 0 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 1 0.000000000000 1.000000000000 0.000000000000 0.000000000000
# 2 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 3 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 4 2.000000000000 0.000000000000 1.000000000000 0.000000000000
#
#   Country_of_Origin               Region_of_Origin  \
# 0         Guatemala                Central America
# 1           Unknown  Latin America / Caribbean (P)
# 2           Unknown  Latin America / Caribbean (P)
# 3            Mexico                Central America
# 4             Sudan                Northern Africa
#
#                     Cause_of_Death       Country_of_Incident  \
# 0                 Mixed or unknown  United States of America
# 1                 Mixed or unknown  United States of America
# 2                 Mixed or unknown  United States of America
# 3                         Violence  United States of America
# 4  Lack of Shelter, Food, or Water        Russian Federation
#
#              Migration_Route  \
# 0  US-Mexico border crossing
# 1  US-Mexico border crossing
# 2  US-Mexico border crossing
# 3  US-Mexico border crossing
# 4              Not Specified
#
#                                 Location_Description             Coordinates  \
# 0  Pima Country Office of the Medical Examiner ju...  31.650259, -110.366453
# 1  Pima Country Office of the Medical Examiner ju...    31.59713, -111.73756
# 2  Pima Country Office of the Medical Examiner ju...    31.94026, -113.01125
# 3                         near Douglas, Arizona, USA  31.506777, -109.315632
# 4                  Border between Russia and Estonia             59.1551, 28
#
#   UNSD_Geographical_Grouping  \
# 0           Northern America
# 1           Northern America
# 2           Northern America
# 3           Northern America
# 4            Northern Europe
#
#                                   Information_Source  \
# 0  Pima County Office of the Medical Examiner (PC...
# 1  Pima County Office of the Medical Examiner (PC...
# 2  Pima County Office of the Medical Examiner (PC...
# 3  Ministry of Foreign Affairs Mexico, Pima Count...
# 4                  EUBusiness (Agence France-Presse)
#
#                           URL Source_Quality
# 0  http://humaneborders.info/              5
# 1                         NaN              5
# 2                         NaN              5
# 3       http://bit.ly/1qfIw00              5
# 4       http://bit.ly/1rTFTjR              1

# %%
# Get Dummies to One-Hot-Encode the Causes of Death
MM = pd.get_dummies(MM, columns = ['Cause_of_Death'], prefix = "COD", prefix_sep = '_')

# %%
len(MM)
# Out:
# 20132

# %% [markdown]
# ## E: Getting Lattitude and Longitude Data

# %%
'''Coordinates from IOM come in a string that includes text and other characters
It also comes as longitude - latitude, so they will be flipped in the next portion
Erasing the String Data within the Coordinates Column
Convert Coordinates into a list for future processing
'''
#
index = 0
for i in MM['Coordinates']:
    #MM['Coordinates'][index][0] = MM['Coordinates'][index][0].strip(',')
    MM['Coordinates'][index] = str(MM['Coordinates'][index])
    #MM['Coordinates'][index] = MM["Coordinates"][index].strip('POINT (').strip(')')
    MM['Coordinates'][index] = MM["Coordinates"][index].strip(',')
    #MM['Coordinates'][index][0] = MM['Coordinates'][index][0].strip(',')
    MM['Coordinates'][index] = MM['Coordinates'][index].split(' ')
    index = index + 1
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
index = 0
for i in MM['Coordinates']:
    MM['Coordinates'][index][0] = MM['Coordinates'][index][0].strip(',')
    index=index+1
    
print(MM['Coordinates'])
# Out:
# 0           [31.650259, -110.366453]
# 1             [31.59713, -111.73756]
# 2             [31.94026, -113.01125]
# 3           [31.506777, -109.315632]
# 4                      [59.1551, 28]
#                     ...
# 20127     [55.80967786, 27.04253439]
# 20128     [35.51646293, 11.07677513]
# 20129    [35.87939725, -5.334128056]
# 20130     [35.8956652, -5.309203848]
# 20131     [35.87415129, -5.32748803]
# Name: Coordinates, Length: 20132, dtype: object

# %%
# Separating the coordinates of the incident into latitude and longitude, part 1:

index = 0
latlist = []
longlist = []
for items in range(0,len(MM)):
    if len(MM['Coordinates'][index]) != 2:
        MM['Coordinates'][index] = [0,0]
        #print(MM["Coordinates"][index])
        latlist.append(float(MM['Coordinates'][index][0]))
        longlist.append(float(MM['Coordinates'][index][1]))
    else:
        latlist.append(float(MM['Coordinates'][index][0]))
        longlist.append(float(MM['Coordinates'][index][1]))
    index = index + 1

# %%
# Separating the coordinates of the incident into latitude and longitude, part 2:
# Assigning the lists to columns

MM["Latitude"] = latlist
MM["Longitude"] = longlist
MM.columns
# Out:
# Index(['Incident_ID', 'Incident_Type', 'Region', 'Reported_Date',
#        'Reported_Year', 'Reported_Month', 'Number_Dead', 'Minimum_Missing',
#        'Total_Dead_and_Missing', 'Survivors', 'Females', 'Males', 'Children',
#        'Country_of_Origin', 'Region_of_Origin', 'Country_of_Incident',
#        'Migration_Route', 'Location_Description', 'Coordinates',
#        'UNSD_Geographical_Grouping', 'Information_Source', 'URL',
#        'Source_Quality', 'COD_Accidental death', 'COD_Drowning',
#        'COD_Lack of Shelter, Food, or Water', 'COD_Mixed or unknown',
#        'COD_Sickness / lack of access to adequate healthcare',
#        'COD_Vehicle accident / death linked to hazardous transport',
#        'COD_Violence', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Ensure that lat-long and coordinates match
MM[["Latitude", "Longitude", "Coordinates"]]
# Out:
#              Latitude         Longitude                  Coordinates
# 0     31.650259000000 -110.366453000000     [31.650259, -110.366453]
# 1     31.597130000000 -111.737560000000       [31.59713, -111.73756]
# 2     31.940260000000 -113.011250000000       [31.94026, -113.01125]
# 3     31.506777000000 -109.315632000000     [31.506777, -109.315632]
# 4     59.155100000000   28.000000000000                [59.1551, 28]
# ...               ...               ...                          ...
# 20127 55.809677860000   27.042534390000   [55.80967786, 27.04253439]
# 20128 35.516462930000   11.076775130000   [35.51646293, 11.07677513]
# 20129 35.879397250000   -5.334128056000  [35.87939725, -5.334128056]
# 20130 35.895665200000   -5.309203848000   [35.8956652, -5.309203848]
# 20131 35.874151290000   -5.327488030000   [35.87415129, -5.32748803]
#
# [20132 rows x 3 columns]

# %%
# Coercing into float
MM['Total_Dead_and_Missing'] = MM["Total_Dead_and_Missing"].astype(float)

# %%
# E. Creating Log_Dead to Normalize Size of Bubbles on Maps part 1:
# Creating two empty lists to be filled later. 
deadlist = []
logdeadlist = []

# E. Creating Log_Dead to Normalize Size of Bubbles on Maps part 3:
# Creating a list of the relevant values
for i, row in MM.iterrows():
    deadlist.append(MM.at[i, "Total_Dead_and_Missing"])

# E. Creating Log_Dead to Normalize Size of Bubbles on Maps part 4:
# Logging the elements of the list
for dead in deadlist:
    logdeadlist.append(dead**(1/3)*3)
MM["Log_Dead"] = logdeadlist

# %%
#F. Cleaning the URL to get just one 

MM['URL'] = MM['URL'].replace(np.nan, "Not Given")

URL1 = []

for url in MM["URL"]:
    url = url.split(",")
    URL1.append(url[0])

#Assigning the value to a column
MM["URL1"] = URL1

# %%
#G creating variables for unknown sex and age
MM = MM.assign(Unknown_Sex = MM.Total_Dead_and_Missing -  MM.Females -  MM.Males, Unknown_Age_Status = MM.Total_Dead_and_Missing -  MM.Children)

# %%
print(MM.head())
# Out:
#      Incident_ID Incident_Type         Region Reported_Date  Reported_Year  \
# 0  2014.MMP00001      Incident  North America    2014-01-06           2014
# 1  2014.MMP00002      Incident  North America    2014-01-12           2014
# 2  2014.MMP00003      Incident  North America    2014-01-14           2014
# 3  2014.MMP00004      Incident  North America    2014-01-16           2014
# 4  2014.MMP00005      Incident         Europe    2014-01-16           2014
#
#   Reported_Month    Number_Dead  Minimum_Missing  Total_Dead_and_Missing  \
# 0        January 1.000000000000   0.000000000000          1.000000000000
# 1        January 1.000000000000   0.000000000000          1.000000000000
# 2        January 1.000000000000   0.000000000000          1.000000000000
# 3        January 1.000000000000   0.000000000000          1.000000000000
# 4        January 1.000000000000   0.000000000000          1.000000000000
#
#        Survivors        Females          Males       Children  \
# 0 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 1 0.000000000000 1.000000000000 0.000000000000 0.000000000000
# 2 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 3 0.000000000000 0.000000000000 1.000000000000 0.000000000000
# 4 2.000000000000 0.000000000000 1.000000000000 0.000000000000
#
#   Country_of_Origin               Region_of_Origin       Country_of_Incident  \
# 0         Guatemala                Central America  United States of America
# 1           Unknown  Latin America / Caribbean (P)  United States of America
# 2           Unknown  Latin America / Caribbean (P)  United States of America
# 3            Mexico                Central America  United States of America
# 4             Sudan                Northern Africa        Russian Federation
#
#              Migration_Route  \
# 0  US-Mexico border crossing
# 1  US-Mexico border crossing
# 2  US-Mexico border crossing
# 3  US-Mexico border crossing
# 4              Not Specified
#
#                                 Location_Description  \
# 0  Pima Country Office of the Medical Examiner ju...
# 1  Pima Country Office of the Medical Examiner ju...
# 2  Pima Country Office of the Medical Examiner ju...
# 3                         near Douglas, Arizona, USA
# 4                  Border between Russia and Estonia
#
#                 Coordinates UNSD_Geographical_Grouping  \
# 0  [31.650259, -110.366453]           Northern America
# 1    [31.59713, -111.73756]           Northern America
# 2    [31.94026, -113.01125]           Northern America
# 3  [31.506777, -109.315632]           Northern America
# 4             [59.1551, 28]            Northern Europe
#
#                                   Information_Source  \
# 0  Pima County Office of the Medical Examiner (PC...
# 1  Pima County Office of the Medical Examiner (PC...
# 2  Pima County Office of the Medical Examiner (PC...
# 3  Ministry of Foreign Affairs Mexico, Pima Count...
# 4                  EUBusiness (Agence France-Presse)
#
#                           URL Source_Quality  COD_Accidental death  \
# 0  http://humaneborders.info/              5                 False
# 1                   Not Given              5                 False
# 2                   Not Given              5                 False
# 3       http://bit.ly/1qfIw00              5                 False
# 4       http://bit.ly/1rTFTjR              1                 False
#
#    COD_Drowning  COD_Lack of Shelter, Food, or Water  COD_Mixed or unknown  \
# 0         False                                False                  True
# 1         False                                False                  True
# 2         False                                False                  True
# 3         False                                False                 False
# 4         False                                 True                 False
#
#    COD_Sickness / lack of access to adequate healthcare  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    COD_Vehicle accident / death linked to hazardous transport  COD_Violence  \
# 0                                              False                  False
# 1                                              False                  False
# 2                                              False                  False
# 3                                              False                   True
# 4                                              False                  False
#
#          Latitude         Longitude       Log_Dead  \
# 0 31.650259000000 -110.366453000000 3.000000000000
# 1 31.597130000000 -111.737560000000 3.000000000000
# 2 31.940260000000 -113.011250000000 3.000000000000
# 3 31.506777000000 -109.315632000000 3.000000000000
# 4 59.155100000000   28.000000000000 3.000000000000
#
#                          URL1    Unknown_Sex  Unknown_Age_Status
# 0  http://humaneborders.info/ 0.000000000000      1.000000000000
# 1                   Not Given 0.000000000000      1.000000000000
# 2                   Not Given 0.000000000000      1.000000000000
# 3       http://bit.ly/1qfIw00 0.000000000000      1.000000000000
# 4       http://bit.ly/1rTFTjR 0.000000000000      1.000000000000

# %% [markdown]
# ## F: Reverse Geocoding to Create Country Column

# %% [markdown]
# ## Warning:
# **This process will take about two hours to run through**

# %%
#H. Finding the country of the incident according to the coordinates part 1:
#Defining a function that finds the country name
'''
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MissingMigrants")
def country_name(coord):
    location = geolocator.reverse(coord, exactly_one=True, language = "en")
    address = location.raw['address']
    city = address.get('city', '')
    state = address.get('state', '')
    country = address.get('country', '')
    return country
    '''
# Out:
# '\nfrom geopy.geocoders import Nominatim\ngeolocator = Nominatim(user_agent="MissingMigrants")\ndef country_name(coord):\n    location = geolocator.reverse(coord, exactly_one=True, language = "en")\n    address = location.raw[\'address\']\n    city = address.get(\'city\', \'\')\n    state = address.get(\'state\', \'\')\n    country = address.get(\'country\', \'\')\n    return country\n    '

# %%
#Applying the function to each of the elements in "Coordinates"
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MissingMigrants")
def country_name(coord):
    location = geolocator.reverse(coord, exactly_one=True, language = "en")
    address = location.raw['address']
    city = address.get('city', '')
    state = address.get('state', '')
    country = address.get('country', '')
    return country

countries =[]
index = 0
for i in MM["Coordinates"]:
    try:
        countries.append(country_name([MM['Latitude'][index], MM['Longitude'][index]]))
    except:
        countries.append("International Waters")
        
    index = index + 1

# %%
#H. Finding the country of the incident according to the coordinates part 2:
#Applying the function to each of the elements in "Coordinates"
#Storing country name in a list.
'''
countries =[]
index = 0
for i in MM["Coordinates"]:
    try:
        countries.append(country_name([MM['Latitude'][index], MM['Longitude'][index]]))
    except:
        countries.append("International Waters")
        
    index = index + 1
'''

# %%
#H. Finding the country of the incident according to the coordinates part 3:
#Looking at how many coordinates were paired with countries. It should be close to 8000.
print(len(countries))

# %%
#H. Finding the country of the incident according to the coordinates part 4:
#Assigning the values to a new column

MM["Country"] = countries
MM['Country'] = MM['Country'].replace(np.nan, "International Waters")

# %%
# Second Check
# The function sometimes returned 0.0 as an error
# So checking to see if it is a float

index = 0
for i in MM["Country"]:
    if type(MM['Country'][index]) == float:
        MM['Country'][index] = "Not Found"
    else:
        pass
    index = index + 1

# %%
index = -1
for i in MM['Country']:
    index = index + 1
    if MM['Country'][index] == "":
        MM['Country'][index] = "Not Found"
    else:
        pass

# %%
index = -1
for i in MM['Country']:
    index = index + 1
    MM['Country'][index] = str(MM['Country'][index])
    print(MM['Country'][index])
# Out:
# United States
# United States
# United States
# Spain
# United States
# Mexico
# United States
# Mexico
# Mexico
# Mexico
# Mexico
# Mauritania
# Italy
# Libya
# United States
# Libya
# Lebanon
# Spain
# Mexico
# Mexico
# Italy
# Trinidad and Tobago
# United States
# United States
# United States
# United States
# United States
# Morocco
# International Waters
# Lebanon
# Spain
# Turkey
# United States
# Spain
# Indonesia
# United States
# Indonesia
# United States
# United States
    MM['Country'][i] = str(MM['Country'][i])

# %%
new_col = ['Incident_ID', 'Incident_Type', 'Region', 'Reported_Date',
       'Reported_Year', 'Reported_Month', 'Number_Dead', 'Minimum_Missing',
       'Total_Dead_and_Missing', 'Survivors', 'Females', 'Males', 'Children', "Country of Origin",
       'Region of Origin', 'Country of Incident', 'Migration Route',
       'Location Description', 'Coordinates', 'UNSD_Geographical_Grouping',
       'Info Source', 'URL', 'Source Quality', 'Other Accidents',
       'Drowning', 'Lack of Shelter, Food, or Water',
       'Mixed or unknown',
       'Sickness',
       'Transportation Accident',
       'Violence', 'Latitude', 'Longitude', 'Log_Dead', 'URL1',
       'Unknown_Sex', 'Unknown_Age_Status', 'Country']

# %%
MM.columns = new_col

# %%
for i in range (0,len(MM['Total_Dead_and_Missing'])):
    if type(MM['Total_Dead_and_Missing'][i]) == str:
        if ',' in MM['Total_Dead_and_Missing'][i]:
            MM['Total_Dead_and_Missing'][i] = MM['Total_Dead_and_Missing'][i].replace(",", "")
        else:
            pass
    else:
        pass
    
    MM['Total_Dead_and_Missing'][i] = float(MM['Total_Dead_and_Missing'][i])

confirmed_adults = []
index = 0
for i in MM['Children']:
    MM['Males'][index] = float(MM['Males'][index])
    MM['Females'][index] = float(MM['Females'][index])
    MM['Children'][index] = float(MM['Children'][index])
    MM['Unknown_Age_Status'][index] = float(MM['Unknown_Age_Status'][index])
    #digit = MM['Males'][index] + MM['Females'][index] - MM['Children'][index] - MM['Unknown_Age_Status'][index]
    #confirmed_adults.append[digit]
    index = index + 1
    
confirmed_adults = []
index = 0
for i in MM['Children']:
    if MM["Unknown_Age_Status"][index] != 0:
        digit = MM['Males'][index] + MM['Females'][index] - MM['Children'][index]
        confirmed_adults.append(digit)
    else:
        confirmed_adults.append(0)
    index = index + 1

index = 0
Children_Sum = []
for i in MM['Children']:
    Children_Sum.append(float(MM['Children'][index]))
    index = index + 1
    
index = 0
Total_Minus_Unknown = []
for i in MM['Children']:
    Total_Minus_Unknown.append(float(MM['Total_Dead_and_Missing'][index]) - float((MM['Unknown_Age_Status'][index])))
    index = index + 1

# %%
print(sum(Children_Sum))
print(sum(Total_Minus_Unknown))
print(sum(confirmed_adults))
print(sum(MM['Unknown_Age_Status']))

# %%
MM['Confirmed_Adults'] = confirmed_adults

# %%
#Format the date to datetime
import datetime
# Date parser to pass to read_csv
d = lambda x: pd.datetime.strptime(x, '%d-%b-%y')
dt_list = []
index = 0
month_key = {"January": "01",
            "February": "02",
            "March" : "03",
            "April" : "04",
            "May": "05",
            "June": "06",
            "July": "07",
            "August": "08",
            "September": "09",
            "October": "10",
            "November": "11",
            "December": "12"}

for i in MM['Reported_Year']:
    dt_list.append(str(MM['Reported_Year'][index])+ '-' + month_key[str(MM["Reported_Month"][index])]+ '-' + "01")
    index = index + 1
    
MM['Date'] = pd.to_datetime(dt_list)

# %%
#Find your current working directory
#import os
#os.getcwd()

# %%
MM.to_csv(r'/Users/liamcomerweaver/Documents/Coding/Python Scripts/CSVs/MM_Dummies_OCT25.csv', index=False)
